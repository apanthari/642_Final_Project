# %%
pip install git+https://github.com/PaulMcInnis/JobFunnel.git
# Out:
# ...
#   Cloning https://github.com/PaulMcInnis/JobFunnel.git to c:\users\panth\appdata\local\temp\pip-req-build-vtnrf3sd
#   Resolved https://github.com/PaulMcInnis/JobFunnel.git to commit 493af1bbdc8b846b630a1b0e2cedb2eb02ab7f4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/PaulMcInnis/JobFunnel.git 'C:\Users\panth\AppData\Local\Temp\pip-req-build-vtnrf3sd'

# %%
# !pip install wget
import wget

# %%
# !wget https://raw.githubusercontent.com/PaulMcInnis/JobFunnel/master/demo/settings.yaml -O settings_USA.yaml
# Out:
# --2024-10-25 13:13:11--  https://raw.githubusercontent.com/PaulMcInnis/JobFunnel/master/demo/settings.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2381 (2.3K) [text/plain]
# Saving to: 'settings_USA.yaml'
#
#      0K ..                                                    100%  334K=0.007s
#
# 2024-10-25 13:13:11 (334 KB/s) - 'settings_USA.yaml' saved [2381/2381]

# %%
# !funnel load -s settings_USA.yaml
# Out:
# [2024-10-25 13:13:46,663] [INFO] JobFunnel: Scraping local providers with: ['IndeedScraperCANEng', 'MonsterScraperCANEng']
# [2024-10-25 13:13:48,252] [INFO] IndeedScraperCANEng: Found 5 pages of search results for query=Python
# [2024-10-25 13:13:50,626] [INFO] IndeedScraperCANEng: Scraped 125 job listings from search results pages
# [2024-10-25 13:13:50,767] [ERROR] IndeedScraperCANEng: Job Principal Site Reliability Administrator and Principal Site Reliability Administrator share duplicate key_id: IndeedScraperCANEng_dedfdb2662e61b80
# [2024-10-25 13:13:50,767] [ERROR] IndeedScraperCANEng: Job Full Stack Developer and Full Stack Developer share duplicate key_id: IndeedScraperCANEng_1ff87ce8f4514519
# [2024-10-25 13:13:50,796] [INFO] MonsterScraperCANEng: No get() or set() will be done for Job attrs: ['REMOTENESS']
# [2024-10-25 13:13:51,613] [ERROR] JobFunnel: Failed to scrape jobs for MonsterScraperCANEng: Unable to extract jobs from initial search result page:
# ...

# %%
import pandas as pd
df = pd.read_csv('demo_search.csv')

# %%
df
# Out:
#     status                                              title  \
# 0      NEW                                Senior Data Analyst
# 1      NEW                 Student Researcher, PhD, Fall 2024
# 2      NEW  Intermediate Analyst, Actuarial- Personal Pricing
# 3      NEW    Intermediate Technology Specialist, Integration
# 4      NEW                  Research Intern, PhD, Summer 2025
# ..     ...                                                ...
# 118    NEW                 Senior Embedded Software Developer
# 119    NEW           Principal Site Reliability Administrator
# 120    NEW                                 Senior QA Engineer
# 121    NEW                              Expert Coding Trainer
# 122    NEW  Étudiant-chercheur, baccalauréat ou maîtrise, ...
#
#                             company       location        date  \
# 0                          Sun Life   Waterloo, ON  2024-09-25
# 1                            Google   Waterloo, ON  2024-10-09
# ...

# %%
# !column -s, -t < master_list.csv | less -#2 -N -S
# Out:
# The system cannot find the file specified.
